# %%
import calibration

test_path = 'predictions/rally6_v2/court_keypoints.csv'
avg = calibration.get_avg_keypoints(test_path)
# Out:
# Before filtering: (1630, 19)
# After filtering: (1630, 19)

# %%
def get_court_accuracy(avg_keypoints, gt):
    print()
